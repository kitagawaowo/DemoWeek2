# %% [markdown]
# <a href="https://colab.research.google.com/github/kitagawaowo/DemoWeek2/blob/main/week2Mobile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Desarrollo Mobile con kotlin

# %% [markdown]
# URL invertida para el package name
# Broadcast, activities
#
# Dentro del manifest tenemos que colocar todas las pantallas que van a tener la aplicacion.
#
# Una pantalla tiene que tener un flujo de aplicacion.

# %% [markdown]
# ![Screenshot 2023-03-28 at 13.35.17.png](data:image/png;base64,...)
#
#
# Definicion segun las pantallas
# ![Screenshot 2023-03-28 at 13.36.32.png](data:image/png;base64,...)
#
# Una activdad es una pantalla
# onCReate se llama automaticamente al iniciar
# ![Screenshot 2023-03-28 at 13.39.16.png](data:image/png;base64,...)

# %% [markdown]
# Los Composable deben iniciar con Mayuscula y no pertenecen a ninguna clase
#
# Preview hace una vista previa al ejecutarlo
# ![Screenshot 2023-03-28 at 13.41.44.png](data:image/png;base64,...)
#
# Creando una funcion Composable Uwu
# ![Screenshot 2023-03-28 at 13.49.57.png](data:image/png;base64,...)
#
# Usando la opcion split podemos observar el deflaut prveiew
# ![Screenshot 2023-03-28 at 13.54.55.png](data:image/png;base64,...)
